# %%
with open("./datasets/rosalind_dna.txt", "r") as dataset:
    sequence = dataset.read()

    A = sequence.count("A")
    C = sequence.count("C")
    G = sequence.count("G")
    T = sequence.count("T")

    print(A, C, G, T)
# Out:
# 216 176 205 204
